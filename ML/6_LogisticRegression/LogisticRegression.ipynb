# %%
import pandas as pd
from sklearn import linear_model
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Age_Insurance.csv")
df.tail()
# Out:
#     age  insurance_bought
# 11   40                 1
# 12   45                 1
# 13   55                 1
# 14   65                 1
# 15   48                 0

# %%
plt.scatter(df.age,df.insurance_bought,color="red")
plt.xlabel("Age")
plt.ylabel("Insurance Bought")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['age']],df.insurance_bought,train_size=0.9)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
model.predict(x_test)
# Out:
# array([0, 0])

# %%
model.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.score(x_test,y_test)
#
# NameError: name 'model' is not defined

# %%
y_test
# Out:
# 5    0
# 3    0
# Name: insurance_bought, dtype: int64
