# %%
# Define a class cars with attributes cartype and model, with a method a startEngine

class cars():
    globalname = "cars"  # class attribute 
    
    def __init__(self,carname,model):
        self.carname = carname    # Instance variable 
        self.model = model            # Instance variable 
        print("Object is created")

    def startEngine(self):
        print("Start the engine",self.carname)


alto = cars("Maruthi","Alto")
nexon = cars("Tata","Nexon")
print(alto.carname , alto.model) # instnace variables
print(nexon.carname , nexon.model) # instnace variables
print(alto.globalname)
print(nexon.globalname)
alto.startEngine()
cars.globalname = "ElectricCars"
print(alto.globalname)
print(nexon.globalname)
# Out:
# Object is created
# Object is created
# Maruthi Alto
# Tata Nexon
# cars
# cars
# Start the engine Maruthi
# ElectricCars
# ElectricCars

# %%
""
