# %%
import textutils as txt
str = txt.remove_urls('https://kfocusacademy.com aaaa bbbb')
print(str)
# Out:
#  aaaa bbbb

# %%
import textutils as txt
str = txt.get_top_keywords("my name is ravi, my father name is apparao")
print(str)
# Out:
# [('my', 2), ('name', 2), ('is', 2), ('ravi,', 1), ('father', 1)]
